# %% [markdown]
# # Data QA
# #### Last Updated: 2019 June 14

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = (6,6)

# %% [markdown]
# Goal is to associate risk of account with risk of entity.
# Behavioral is based on account.
# Acceptance risk - see risk tables (XL files).
#
# ### Part 1
# Columns with 1) entity something and 2) behavioural risk. *Assign continuous risk for entity using acceptance model.* Metrics.
#
# ### Part 2
# Linear regression and comparative metrics.
#
# ### Part 3
# Try other regression types (logarithmic, decision tree, etc)

# %%
bRisk = pd.read_csv('../behavioural_risk.csv', sep = ";")
bRisk.head()
bRisk.sort_values(by = "account_number").head()

# %%
accounts = pd.read_csv('../accounts.csv', sep = ";")
accounts.head()
accounts.sort_values(by = "account_number").head()
# Out:
#        client_number  account_number
# 0                195        19510001
# 24395            195        19519001
# 24522            195        19519002
# 1                292        29210001
# 2                486        48610001

# %%
entities = pd.read_csv('../entities.csv', sep = ";")
entities.head()
# Out:
#    entity_number entity_type  date_of_birth qualifications_code  \
# 0              2           P       19460908                   4
# 1              3           P       19391124                   4
# 2              4           P       19460101                   2
# 3              5           P       19760709                   1
# 4              6           P       19700328                   3
#
#    occupation_activity_code  occupation_code nationality_code  \
# 0                      90.0              NaN              CPV
# 1                      10.0              NaN              PRT
# 2                      13.0              NaN              PRT
# 3                      90.0              NaN              CPV
# 4                      13.0              NaN              CPV
#
#   country_of_residence_code  economic_activity_main_code  \
# 0                       CPV                          NaN
# 1                       PRT                          NaN
# 2                       PRT                          NaN
# 3                       CPV                          NaN
# 4                       CPV                          NaN
#
#    economic_activity_sec_code  ...  country_of_residence_risk cutoff_cl  \
# 0                         NaN  ...                          1         0
# 1                         NaN  ...                          2         0
# 2                         NaN  ...                          2         0
# 3                         NaN  ...                          1         0
# 4                         NaN  ...                          1         0
#
#   economic_activity_code_risk nationality_risk  occupation_risk  \
# 0                         NaN              1.0              4.0
# 1                         NaN              2.0              4.0
# 2                         NaN              2.0              2.0
# 3                         NaN              1.0              4.0
# 4                         NaN              1.0              2.0
#
#    qualifications_risk       reg     score  seg  society_type_risk
# 0                  4.0  0.241569  0.290509    P                NaN
# 1                  4.0  0.411046  0.423553    P                NaN
# 2                  2.0  0.250000  0.268998    P                NaN
# 3                  3.0  0.226793  0.269547    P                NaN
# 4                  3.0  0.095298  0.145518    P                NaN
#
# [5 rows x 36 columns]

# %%
entities.shape
# Out:
# (65535, 36)

# %%
clients = pd.read_csv('../entity_client.csv', sep = ";")
clients.head()
# Out:
#    client_number  entity_number  is_first
# 0            389              4      True
# 1            486              5      True
# 2            583              6      True
# 3            971              8      True
# 4           1359             15      True

# %% [markdown]
# `is_first` means the entity is the main/more powerful of the client
# **an entity is a person** This is not a relevant column so we shall delete it.

# %%
del clients["is_first"]
clients.dtypes
# Out:
# client_number    int64
# entity_number    int64
# dtype: object

# %%
bRisk.sort_values(by = "account_number").head()
# Out:
#        account_number  continuous_risk  discrete_risk
# 5536         19510001         0.454530              3
# 22872        48610001         0.112144              1
# 29024        58310001         0.085539              1
# 3613         68010001         0.329948              2
# 32169        68019006         0.045224              1

# %%
risk_per_acc = accounts.merge(bRisk)
risk_per_acc.head()
# Out:
#    client_number  account_number  continuous_risk  discrete_risk
# 0            195        19510001         0.454530              3
# 1            486        48610001         0.112144              1
# 2            583        58310001         0.085539              1
# 3            680        68010001         0.329948              2
# 4            777        77710001         0.161343              1

# %%
numbers = clients.merge(risk_per_acc)
numbers.head()
# Out:
#    client_number  entity_number  account_number  continuous_risk  \
# 0            486              5        48610001         0.112144
# 1            583              6        58310001         0.085539
# 2            971              8        97110001         0.179198
# 3            971              8        97119005         0.095819
# 4           1359             15       135910001         0.179872
#
#    discrete_risk
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ## Duplicates
#
# We need to check for duplicates to assure the quality of our data. First we will look at the unique client-entity identifiers, then the client-account numbers.
#
# ### Unique entities

# %%
clients.client_number.value_counts().head()
# Out:
# 73236      16
# 74303      16
# 2842489    11
# 510221     10
# 1826414    10
# Name: client_number, dtype: int64

# %%
clients.entity_number.value_counts().head()
# Out:
# 25652    22
# 15078    19
# 5993     16
# 1699     16
# 18560    14
# Name: entity_number, dtype: int64

# %% [markdown]
# Here we can see that there are repeated entity numbers and repeated client numbers. To make sure there are not two repeated values connected, we will create a `unique_entities` column and check the value counts on those.

# %%
clients['unique_entities'] = clients.client_number.astype(str).str.cat(
    [clients.entity_number.astype(str)],sep='-')

# %%
clients.unique_entities.value_counts().head()
# Out:
# 1255472-15549    1
# 1922929-23285    1
# 2266697-27138    1
# 3916279-45639    1
# 2184829-26183    1
# Name: unique_entities, dtype: int64

# %% [markdown]
# The `unique_entities` column has no duplicates.

# %% [markdown]
# ### Unique Accounts

# %%
accounts.client_number.value_counts().head()
# Out:
# 6015       12
# 22311      12
# 2282993    12
# 112133     12
# 3183153    12
# Name: client_number, dtype: int64

# %%
accounts.account_number.value_counts().head()
# Out:
# 510055210001    1
# 409097610001    1
# 343826310001    1
# 607753610001    1
# 568022410001    1
# Name: account_number, dtype: int64

# %% [markdown]
# We can see here that all the account numbers are unique, but we shall create a `unique_accounts` column just in case

# %%
accounts['unique_accounts'] = accounts.client_number.astype(str).str.cat(
    [accounts.account_number.astype(str)],sep='-')

# %%
accounts.unique_accounts.value_counts().head()
# Out:
# 423794-42379415002      1
# 3282093-328209311001    1
# 2457302-245730210001    1
# 5928835-592883510001    1
# 2109945-210994510001    1
# Name: unique_accounts, dtype: int64

# %% [markdown]
# There are no duplicates! We can delete the unique columns.

# %%
del clients["unique_entities"]
del accounts["unique_accounts"]

# %% [markdown]
#  As a final check for duplicates we will make a unique column in the `numbers` dataframe.

# %%
numbers['unique_id'] = numbers.client_number.astype(str).str.cat(
    [numbers.account_number.astype(str), numbers.entity_number.astype(str)],sep='-')

# %%
numbers.unique_id.value_counts().head()
# Out:
# 1751627-175162710001-21315    1
# 2656637-265663710001-31408    1
# 367340-36734010001-3562       1
# 318937-31893710001-4370       1
# 1958722-195872210001-23689    1
# Name: unique_id, dtype: int64

# %% [markdown]
# All are unique, there are no duplicates.

# %% [markdown]
# Next we will begin wading through the variables in the `entities` dataframe.

# %%
entities.head(10)
# Out:
#    entity_number entity_type  date_of_birth qualifications_code  \
# 0              2           P       19460908                   4
# 1              3           P       19391124                   4
# 2              4           P       19460101                   2
# 3              5           P       19760709                   1
# 4              6           P       19700328                   3
# 5              7           P       19770506                   2
# 6              8           P       19680330                   4
# 7              9           P       19730620                   2
# 8             10           P       19710222                   4
# 9             11           P       19720119                   4
#
#    occupation_activity_code  occupation_code nationality_code  \
# 0                      90.0              NaN              CPV
# 1                      10.0              NaN              PRT
# 2                      13.0              NaN              PRT
# 3                      90.0              NaN              CPV
# 4                      13.0              NaN              CPV
# 5                      13.0              NaN              CPV
# 6                      13.0              NaN              CPV
# 7                      13.0              NaN              CPV
# 8                      13.0              NaN              CPV
# 9                      10.0              NaN              CPV
#
#   country_of_residence_code  economic_activity_main_code  \
# 0                       CPV                          NaN
# 1                       PRT                          NaN
# 2                       PRT                          NaN
# 3                       CPV                          NaN
# 4                       CPV                          NaN
# 5                       CPV                          NaN
# 6                       CPV                          NaN
# 7                       CPV                          NaN
# 8                       CPV                          NaN
# 9                       CPV                          NaN
#
#    economic_activity_sec_code  ...  country_of_residence_risk cutoff_cl  \
# 0                         NaN  ...                          1         0
# 1                         NaN  ...                          2         0
# 2                         NaN  ...                          2         0
# 3                         NaN  ...                          1         0
# 4                         NaN  ...                          1         0
# 5                         NaN  ...                          1         0
# 6                         NaN  ...                          1         0
# 7                         NaN  ...                          1         0
# 8                         NaN  ...                          1         0
# 9                         NaN  ...                          1         0
#
#   economic_activity_code_risk nationality_risk  occupation_risk  \
# 0                         NaN              1.0              4.0
# 1                         NaN              2.0              4.0
# 2                         NaN              2.0              2.0
# 3                         NaN              1.0              4.0
# 4                         NaN              1.0              2.0
# 5                         NaN              1.0              2.0
# 6                         NaN              1.0              2.0
# 7                         NaN              1.0              2.0
# 8                         NaN              1.0              2.0
# 9                         NaN              1.0              4.0
#
#    qualifications_risk       reg     score  seg  society_type_risk
# 0                  4.0  0.241569  0.290509    P                NaN
# 1                  4.0  0.411046  0.423553    P                NaN
# 2                  2.0  0.250000  0.268998    P                NaN
# 3                  3.0  0.226793  0.269547    P                NaN
# 4                  3.0  0.095298  0.145518    P                NaN
# 5                  2.0  0.080523  0.135954    P                NaN
# 6                  4.0  0.110073  0.166481    P                NaN
# 7                  2.0  0.080523  0.135954    P                NaN
# 8                  4.0  0.110073  0.166481    P                NaN
# 9                  4.0  0.241569  0.290509    P                NaN
#
# [10 rows x 36 columns]

# %%
entities.entity_number.value_counts().head()
# Out:
# 2047     1
# 27288    1
# 35524    1
# 45763    1
# 47810    1
# Name: entity_number, dtype: int64

# %% [markdown]
# All `entity_number`s in `entities` are unique. There are no duplicates.

# %%
entities.dtypes
# Out:
# entity_number                      int64
# entity_type                       object
# date_of_birth                      int64
# qualifications_code               object
# occupation_activity_code         float64
# occupation_code                  float64
# nationality_code                  object
# country_of_residence_code         object
# economic_activity_main_code      float64
# economic_activity_sec_code       float64
# date_of_constitution               int64
# society_type_code                 object
# gender                            object
# civil_status                      object
# BC_reg                             int64
# BC_score                           int64
# B_age_risk                       float64
# B_company_age_risk               float64
# B_country_of_residence_risk      float64
# B_economic_activity_code_risk    float64
# B_nationality_risk               float64
# B_occupation_risk                float64
# B_qualifications_risk            float64
# B_society_type_risk              float64
# age_risk                         float64
# company_age_risk                 float64
# country_of_residence_risk          int64
# cutoff_cl                          int64
# economic_activity_code_risk      float64
# nationality_risk                 float64
# occupation_risk                  float64
# qualifications_risk              float64
# reg                              float64
# score                            float64
# seg                               object
# society_type_risk                float64
# dtype: object

# %% [markdown]
# Delete `seg` because it has the same values as entity_type

# %%
del entities["seg"]

# %% [markdown]
# What is `cutoff_cl`?

# %%
entities.loc[(entities["cutoff_cl"] == 0)].head()
# Out:
#    entity_number entity_type  date_of_birth qualifications_code  \
# 0              2           P       19460908                   4
# 1              3           P       19391124                   4
# 2              4           P       19460101                   2
# 3              5           P       19760709                   1
# 4              6           P       19700328                   3
#
#    occupation_activity_code  occupation_code nationality_code  \
# 0                      90.0              NaN              CPV
# 1                      10.0              NaN              PRT
# 2                      13.0              NaN              PRT
# 3                      90.0              NaN              CPV
# 4                      13.0              NaN              CPV
#
#   country_of_residence_code  economic_activity_main_code  \
# 0                       CPV                          NaN
# 1                       PRT                          NaN
# 2                       PRT                          NaN
# 3                       CPV                          NaN
# 4                       CPV                          NaN
#
#    economic_activity_sec_code  ...  company_age_risk  \
# 0                         NaN  ...               NaN
# 1                         NaN  ...               NaN
# 2                         NaN  ...               NaN
# 3                         NaN  ...               NaN
# 4                         NaN  ...               NaN
#
#   country_of_residence_risk cutoff_cl economic_activity_code_risk  \
# 0                         1         0                         NaN
# 1                         2         0                         NaN
# 2                         2         0                         NaN
# 3                         1         0                         NaN
# 4                         1         0                         NaN
#
#    nationality_risk  occupation_risk  qualifications_risk       reg     score  \
# 0               1.0              4.0                  4.0  0.241569  0.290509
# 1               2.0              4.0                  4.0  0.411046  0.423553
# 2               2.0              2.0                  2.0  0.250000  0.268998
# 3               1.0              4.0                  3.0  0.226793  0.269547
# 4               1.0              2.0                  3.0  0.095298  0.145518
#
#    society_type_risk
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 35 columns]

# %%
entities.loc[(entities["cutoff_cl"] == 1)].head()
# Out:
#      entity_number entity_type  date_of_birth qualifications_code  \
# 80              93           E              0                 NaN
# 101            120           E              0                 NaN
# 111            130           P       19480222                   0
# 146            175           E              0                 NaN
# 157            188           P       19391208                   0
#
#      occupation_activity_code  occupation_code nationality_code  \
# 80                        NaN              NaN              NaN
# 101                       NaN              NaN              NaN
# 111                       0.0              NaN              CUB
# 146                       NaN              NaN              NaN
# 157                       0.0              NaN              AGO
#
#     country_of_residence_code  economic_activity_main_code  \
# 80                        NaN                       8890.0
# 101                       CPV                       8890.0
# 111                       CUB                          NaN
# 146                       NaN                          0.0
# 157                       PRT                          NaN
#
#      economic_activity_sec_code  ...  company_age_risk  \
# 80                          NaN  ...               3.0
# 101                         NaN  ...               1.0
# 111                         NaN  ...               NaN
# 146                         NaN  ...               1.0
# 157                         NaN  ...               NaN
#
#     country_of_residence_risk cutoff_cl economic_activity_code_risk  \
# 80                          3         1                         4.0
# 101                         1         1                         4.0
# 111                         5         1                         NaN
# 146                         3         1                         5.0
# 157                         2         1                         NaN
#
#      nationality_risk  occupation_risk  qualifications_risk       reg  \
# 80                NaN              NaN                  NaN  0.468536
# 101               NaN              NaN                  NaN  0.480133
# 111               5.0              5.0                  5.0  1.000000
# 146               NaN              NaN                  NaN  0.507393
# 157               5.0              5.0                  5.0  0.751332
#
#         score  society_type_risk
# 80   0.445717                1.0
# 101  0.440667                4.0
# 111  0.971992                NaN
# 146  0.480677                1.0
# 157  0.724385                NaN
#
# [5 rows x 35 columns]

# %%
entities.date_of_birth.value_counts().head()
# Out:
# 0           4639
# 19820101      23
# 19740101      17
# 19800217      16
# 19800505      16
# Name: date_of_birth, dtype: int64

# %% [markdown]
# There shouldn't be people that have a birth date 0. Could these entities be companies? Or should we flag them as a higher risk?

# %%
#entities.B_age_risk.value_counts().head()

# %%
entities.sort_values(by = "date_of_birth").head(10)
# Out:
#        entity_number entity_type  date_of_birth qualifications_code  \
# 48223          50180           P      -19790222                   B
# 21699          23117           P      -19770215                   0
# 26445          27984           P      -19720928                   4
# 32767          34432           E              0                 NaN
# 35929          37666           E              0                 NaN
# 35935          37672           E              0                 NaN
# 35941          37678           E              0                 NaN
# 35950          37688           E              0                 NaN
# 35959          37697           E              0                 NaN
# 35962          37700           E              0                 NaN
#
#        occupation_activity_code  occupation_code nationality_code  \
# 48223                      11.0              NaN              CPV
# 21699                       0.0              NaN              CPV
# 26445                      13.0              NaN              SEN
# 32767                       NaN              NaN              NaN
# 35929                       NaN              NaN              NaN
# 35935                       NaN              NaN              NaN
# 35941                       NaN              NaN              NaN
# 35950                       NaN              NaN              NaN
# 35959                       NaN              NaN              NaN
# 35962                       NaN              NaN              NaN
#
#       country_of_residence_code  economic_activity_main_code  \
# 48223                       CPV                          NaN
# 21699                       CPV                          NaN
# 26445                       SEN                          NaN
# 32767                       NaN                          0.0
# 35929                       CPV                       6810.0
# 35935                       CPV                          0.0
# 35941                       CPV                       8890.0
# 35950                       CPV                       3601.0
# 35959                       CPV                       8890.0
# 35962                       CPV                       4752.0
#
#        economic_activity_sec_code  ...  company_age_risk  \
# 48223                         NaN  ...               NaN
# 21699                         NaN  ...               NaN
# 26445                         NaN  ...               NaN
# 32767                         NaN  ...               3.0
# 35929                         NaN  ...               1.0
# 35935                         NaN  ...               3.0
# 35941                         NaN  ...               1.0
# 35950                      8890.0  ...               1.0
# 35959                         NaN  ...               3.0
# 35962                         NaN  ...               1.0
#
#       country_of_residence_risk cutoff_cl economic_activity_code_risk  \
# 48223                         1         0                         NaN
# 21699                         1         0                         NaN
# 26445                         3         0                         NaN
# 32767                         3         1                         5.0
# 35929                         1         0                         5.0
# 35935                         1         1                         5.0
# 35941                         1         1                         4.0
# 35950                         1         0                         4.0
# 35959                         1         1                         4.0
# 35962                         1         0                         3.0
#
#        nationality_risk  occupation_risk  qualifications_risk       reg  \
# 48223               1.0              3.0                  1.0  0.131495
# 21699               1.0              5.0                  5.0  0.322092
# 26445               3.0              2.0                  4.0  0.449028
# 32767               NaN              NaN                  NaN  0.692417
# 35929               NaN              NaN                  NaN  0.384834
# 35935               NaN              NaN                  NaN  0.633693
# 35941               NaN              NaN                  NaN  0.480133
# 35950               NaN              NaN                  NaN  0.288625
# 35959               NaN              NaN                  NaN  0.537485
# 35962               NaN              NaN                  NaN  0.383925
#
#           score  society_type_risk
# 48223  0.164413                NaN
# 21699  0.345001                NaN
# 26445  0.412502                NaN
# 32767  0.586571                3.0
# 35929  0.357703                1.0
# 35935  0.550337                4.0
# 35941  0.440667                4.0
# 35950  0.285389                1.0
# 35959  0.478022                4.0
# 35962  0.333252                4.0
#
# [10 rows x 35 columns]

# %%
entities.loc[(entities['date_of_birth'] == 0)].shape
# Out:
# (4639, 35)

# %%
entities.loc[(entities['date_of_birth'] == 0) & (entities["entity_type"] != "P")].shape
# Out:
# (4530, 35)

# %%
entities.loc[(entities['date_of_birth'] == 0) & (entities["entity_type"] == "P")].shape
# Out:
# (109, 35)

# %% [markdown]
# Why are these birth dates negative?

# %%
entities.loc[(entities['date_of_birth'] < 0)]
# Out:
#        entity_number entity_type  date_of_birth qualifications_code  \
# 21699          23117           P      -19770215                   0
# 26445          27984           P      -19720928                   4
# 48223          50180           P      -19790222                   B
#
#        occupation_activity_code  occupation_code nationality_code  \
# 21699                       0.0              NaN              CPV
# 26445                      13.0              NaN              SEN
# 48223                      11.0              NaN              CPV
#
#       country_of_residence_code  economic_activity_main_code  \
# 21699                       CPV                          NaN
# 26445                       SEN                          NaN
# 48223                       CPV                          NaN
#
#        economic_activity_sec_code  ...  company_age_risk  \
# 21699                         NaN  ...               NaN
# 26445                         NaN  ...               NaN
# 48223                         NaN  ...               NaN
#
#       country_of_residence_risk cutoff_cl economic_activity_code_risk  \
# 21699                         1         0                         NaN
# 26445                         3         0                         NaN
# 48223                         1         0                         NaN
#
#        nationality_risk  occupation_risk  qualifications_risk       reg  \
# 21699               1.0              5.0                  5.0  0.322092
# 26445               3.0              2.0                  4.0  0.449028
# 48223               1.0              3.0                  1.0  0.131495
#
#           score  society_type_risk
# 21699  0.345001                NaN
# 26445  0.412502                NaN
# 48223  0.164413                NaN
#
# [3 rows x 35 columns]

# %% [markdown]
# ### Variable Grouping

# %%
entities.nationality_code.value_counts(normalize = True)
# Out:
# CPV    0.738883
# PRT    0.102400
# GNB    0.032323
# ITA    0.013512
# FRA    0.012755
# GBR    0.012442
# ESP    0.010829
# CHN    0.010566
# USA    0.009035
# SEN    0.008410
# NLD    0.007011
# NGA    0.006600
# BRA    0.004625
# DEU    0.002880
# GIN    0.002502
# CUB    0.002271
# AGO    0.002222
# BEL    0.001991
# STP    0.001777
# CHE    0.001745
# IRL    0.001563
# LUX    0.001284
# GHA    0.001086
# SWE    0.000938
# GMB    0.000856
# RUS    0.000757
# IND    0.000708
# MOZ    0.000494
# CMR    0.000494
# SLE    0.000477
#          ...
# TUR    0.000033
# GEO    0.000033
# KOR    0.000033
# RWA    0.000033
# HND    0.000033
# NZL    0.000033
# SOM    0.000033
# NAM    0.000033
# COG    0.000033
# SLV    0.000016
# SGP    0.000016
# CAF    0.000016
# GTM    0.000016
# YUG    0.000016
# LVA    0.000016
# DOM    0.000016
# MYS    0.000016
# SPM    0.000016
# HKG    0.000016
# BYS    0.000016
# GNQ    0.000016
# ARE    0.000016
# ZWE    0.000016
# NCL    0.000016
# NER    0.000016
# MDA    0.000016
# GUF    0.000016
# DZA    0.000016
# MUS    0.000016
# SYC    0.000016
# Name: nationality_code, Length: 109, dtype: float64

# %%
Europe = ["BIH", "BLR", "GIB", "MCO", "RUS", "SRB", "UKR", "YUG", "ALB", "JEY", "MKD", 
          n/ "BGR", "MNE", "LIE", "MDA", CHE, CYP, CZE, FRO, ESP, BYS, EST, GBR, IMN, 
          n/ "ALA", "SMR", "AND", GGY, GRC, HRV, SJM, HUN, ITA, LTU, LVA, MLT, LUX, NLD, POL, PRT, 
          n/ "ROM", "ROU", "SVK", "SVN", "VAT", "AUT", "BEL", "DEU", "DNK", "FIN", "FRA", "IRL", ISL, NOR, SWE]
Asia = ['Midsize Cars']
Africa = ['Large Cars']
North_Central_America =
South_America =
Middle_East =
Carribean =
Oceania =
# Out:
#   File "<ipython-input-3-f6b9da406b10>", line 3
#     n/ "ALA, "SMR, AND, GGY, GRC, HRV, SJM, HUN, ITA, LTU, LVA, MLT, LUX, NLD, POL, PRT,
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Missing values

# %%
n_records = len(entities)
def missing_values_df(df):
    for column in df:
        print("{} | {} | {}".format(
            column, len(df[df[column].isnull()]) / (1.0*n_records), df[column].dtype
        ))

missing_values_df(entities)

# %% [markdown]
# There are several variables with repeated values. The highest are `economic_activity_main_code`, `economic_activity_sec_code`, `B_company_age_risk`, `B_economic_activity_code_risk`, `company_age_risk`, `economic_activity_code_risk`, `society_type_risk` with a values around 0.93.

# %%
def cardinality_categorical(df):
    n_records = len(df)
    for column in df.select_dtypes([object]):
        print("{} | uniques/records: {:.3f} | Minimum observations: {:.3f}".format(
            column, 
            len(df[column].unique())/n_records,
            df[column].value_counts().min()
        ))        

cardinality_categorical(entities)

# %% [markdown]
# ### Grouping Variables

# %%
entities['score'].plot.hist();

# %%
entities['score'].plot.kde();

# %%
def numerical_variable_distribution(df, col):
    df[col].plot.kde()
    plt.xlabel('Variable "{}" Distribution'.format(col))
    plt.show()

# %%
numerical_columns = entities.select_dtypes(include=[np.number]).columns.tolist()

# %%
from ipywidgets import interact, fixed

# %%
interact(numerical_variable_distribution, 
         col=numerical_columns, df=fixed(entities));

# %%
from scipy import stats

# %%
def numerical_variable_normality(col):
    stats.probplot(entities[col], plot=plt)
    plt.xlabel('Probability plot for variable {}'.format(col))
    plt.show()

# %%
interact(numerical_variable_normality, col=numerical_columns);

# %%
for num_col in numerical_columns:
    _, pval = stats.normaltest(entities[num_col][entities[num_col].notnull()])
    if(pval < 0.05):
        print("Column {} doesn't follow a normal distribution".format(num_col))

# %%
def categorical_variable_distribution(col):
    entities[col].value_counts(ascending=True,normalize=True).tail(20).plot.barh()
    plt.show()

# %%
categorical_columns = entities.select_dtypes(
    ['object', 'category']).columns.tolist()

# %%
categorical_columns

# %%
interact(categorical_variable_distribution, col=categorical_columns);

# %%
def pivot_count(df, rows, columns):
    df_pivot = df.pivot_table(values="date_of_constitution", # could be any column, since we are just counting rows 
                              index=rows, 
                              columns=columns, 
                              aggfunc=np.size
                             ).dropna(axis=0, how='all')
    return df_pivot

# %%
pivot1 = pivot_count(entities, "civil_status","nationality_code")
pivot1

# %%
def heatmap_count_types(df, col1, col2):
    pivot_table = pivot_count(df,col1, col2)
    sns.heatmap(pivot_table, annot=True, fmt='g')
    plt.ylabel(col1)
    plt.xlabel(col2)
    plt.show()

# %%
heatmap_count_types(entities, "gender","nationality_code")

# %%
entities.dtypes

# %%
interact(heatmap_count_types, col1=entities.columns.drop(["entity_number", "seg"]),
                                 col2=entities.columns.drop(["entity_number", "seg"]),
                                 df=fixed(entities));
